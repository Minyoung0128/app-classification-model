# %%
import sys
sys.path.append('/home/myk/min0')
sys.path.append('/home/myk/min0/traffic-classification/DataRepresentation/Tokenization')

import tuple2token
import triple2token 
import nprint
import numpy as np
#t = tuple2token.tuple2token('/home/myk/min0/sc_metadata.csv',1,'/home/myk/datasets/sc')

import packet2token

p = packet2token.packet2token('/home/myk/min0/as',900,False)
data = p.train()
np.save('data.npy',data)
# Out:
# /home/myk/min0/as/epicrollercoasters
# /home/myk/min0/as/horizonworkrooms
# /home/myk/min0/as/netflix
# /home/myk/min0/as/hyperdash
# /home/myk/min0/as/bigscreen
# /home/myk/min0/as/campfire
# /home/myk/min0/as/firsttouch
# /home/myk/min0/as/youtube
# /home/myk/min0/as/bigballers
# /home/myk/min0/as/horizonworlds
# /home/myk/min0/as/arkio
# /home/myk/min0/as/gunraiders
# /home/myk/min0/as/roblox
# /home/myk/min0/as/fitxr
# /home/myk/min0/as/gorillatag
# /home/myk/min0/as/blaston
# /home/myk/min0/as/godsofgravity
# /home/myk/min0/as/firsthand
# /home/myk/min0/as/immersed
# /home/myk/min0/as/vrchat

# %%
print(data.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(data.shape)
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
for d in data:
    if len(d) != 3600:
        print(len(d))
# Out:
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# 4500
# ...
